# %% [markdown]
# <a href="https://colab.research.google.com/github/nirmalshah20519/202311043-FOML/blob/main/Assignments/assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 1

# %% [markdown]
# ## 1. Load the Given attached Dataset.

# %%
import numpy as np
import pandas as pd

dataset = pd.read_csv('FOMLHousing.csv')
dataset
# Out:
#         price    area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000  7420.0       4.0        2.0      3.0      yes        no
# 1    12250000  8960.0       4.0        4.0      4.0      yes        no
# 2    12250000  9960.0       3.0        2.0      2.0      yes        no
# 3    12215000     NaN       4.0        2.0      2.0      yes        no
# 4    11410000  7420.0       4.0        1.0      2.0      yes       yes
# ..        ...     ...       ...        ...      ...      ...       ...
# 540   1820000  3000.0       2.0        1.0      1.0      yes        no
# 541   1767150  2400.0       3.0        1.0      1.0       no        no
# 542   1750000  3620.0       2.0        1.0      1.0      yes        no
# 543   1750000  2910.0       3.0        1.0      1.0       no        no
# 544   1750000  3850.0       3.0        1.0      2.0      yes        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %% [markdown]
# ## 2. Find the Measure of the Central Tendency of Area Feature( Mean, Median, Mode)

# %%
area_col=dataset['area']
mean = area_col.mean()
median = area_col.median()
mode = area_col.mode()

print('Mean =',mean)
print('Median =',median)
print('Mode =',mode)
# Out:
# Mean = 5105.255725190839
# Median = 4510.0
# Mode = 0    6000.0
# Name: area, dtype: float64

# %% [markdown]
# ## 3. Plot Histogram for Area Feature

# %%
import matplotlib.pyplot as plt
plt.hist(area_col,bins=10)
plt.xlabel('values')
plt.ylabel('Frequency')
plt.title('Histogram of Area')
# Out:
# Text(0.5, 1.0, 'Histogram of Area')

# %% [markdown]
# ## 4. Plot Boxplot for Area Feature

# %%
# plt.boxplot(dataset['area'])
# plt.xlabel('Column')
# plt.ylabel('Values')
# plt.title('Boxplot of Area Features')
# plt.show()

# %%
import seaborn as sns
sns.boxplot(area_col)
# Out:
# <Axes: >

# %% [markdown]
# ## 5. Plot the scatterplot for Area and Price Features

# %%
price_col=dataset['price']
plt.scatter(area_col,price_col)
plt.xlabel('Area')
plt.ylabel('Price')
plt.title('Scatter Plot of Area and Price Features')
plt.show()

# %% [markdown]
# ## 6. Calculate the covariance and Correlation using the library

# %%
dataset.cov()
# Out:
# <ipython-input-27-418ba3616d2e>:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset.cov()
#                   price          area       bedrooms      bathrooms  \
# price      3.498544e+12  2.118487e+09  510533.077402  485782.872092
# area       2.118487e+09  4.624621e+06     255.573167     212.147504
# bedrooms   5.105331e+05  2.555732e+02       0.543766       0.141721
# bathrooms  4.857829e+05  2.121475e+02       0.141721       0.255003
# stories    6.891153e+05  2.057810e+02       0.260347       0.143339
# parking    6.177181e+05  6.412941e+02       0.086896       0.075400
#
#                  stories        parking
# price      689115.324675  617718.126022
# area          205.780969     641.294106
# bedrooms        0.260347       0.086896
# bathrooms       0.143339       0.075400
# ...

# %%
dataset.corr()
# Out:
# <ipython-input-28-c187c74d1e71>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset.corr()
#               price      area  bedrooms  bathrooms   stories   parking
# price      1.000000  0.534531  0.370164   0.514182  0.423045  0.383785
# area       0.534531  1.000000  0.159982   0.194140  0.109769  0.348171
# bedrooms   0.370164  0.159982  1.000000   0.378832  0.405351  0.136905
# bathrooms  0.514182  0.194140  0.378832   1.000000  0.325402  0.172218
# stories    0.423045  0.109769  0.405351   0.325402  1.000000  0.044803
# parking    0.383785  0.348171  0.136905   0.172218  0.044803  1.000000

# %% [markdown]
# ## 7. Find the Missing Values of all the Features

# %%
dataset.isnull().sum()
# Out:
# price                0
# area                21
# bedrooms             1
# bathrooms            8
# stories              5
# mainroad             4
# guestroom            4
# basement             4
# hotwaterheating      5
# airconditioning      4
# parking              5
# prefarea             5
# furnishingstatus     3
# dtype: int64

# %% [markdown]
# ## 8. Apply the methods to Handle the Missing Value.

# %%
dataset.fillna(dataset.mode(), inplace=True)


dataset
# Out:
#         price         area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000  7420.000000       4.0        2.0      3.0      yes        no
# 1    12250000  8960.000000       4.0        4.0      4.0      yes        no
# 2    12250000  9960.000000       3.0        2.0      2.0      yes        no
# 3    12215000  5105.255725       4.0        2.0      2.0      yes        no
# 4    11410000  7420.000000       4.0        1.0      2.0      yes       yes
# ..        ...          ...       ...        ...      ...      ...       ...
# 540   1820000  3000.000000       2.0        1.0      1.0      yes        no
# 541   1767150  2400.000000       3.0        1.0      1.0       no        no
# 542   1750000  3620.000000       2.0        1.0      1.0      yes        no
# 543   1750000  2910.000000       3.0        1.0      1.0       no        no
# 544   1750000  3850.000000       3.0        1.0      2.0      yes        no
#
# ...

# %%
dataset.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            4
# guestroom           4
# basement            4
# hotwaterheating     5
# airconditioning     4
# parking             0
# prefarea            5
# furnishingstatus    3
# dtype: int64
